# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("C:/Users/lalit/Downloads/BigBasket Products.csv")

# %%
df.head(5)
# Out:
#    index                                            product  \
# 0      1             Garlic Oil - Vegetarian Capsule 500 mg
# 1      2                              Water Bottle - Orange
# 2      3                     Brass Angle Deep - Plain, No.2
# 3      4  Cereal Flip Lid Container/Storage Jar - Assort...
# 4      5                 Creme Soft Soap - For Hands & Body
#
#                  category           sub_category              brand  \
# 0        Beauty & Hygiene              Hair Care  Sri Sri Ayurveda
# 1  Kitchen, Garden & Pets  Storage & Accessories         Mastercook
# 2    Cleaning & Household            Pooja Needs                Trm
# 3    Cleaning & Household   Bins & Bathroom Ware             Nakoda
# 4        Beauty & Hygiene       Bath & Hand Wash              Nivea
#
#    sale_price  market_price                      type  rating  \
# 0       220.0         220.0          Hair Oil & Serum     4.1
# 1       180.0         180.0    Water & Fridge Bottles     2.3
# ...

# %%
df.groupby('category')['brand'].sum()
# Out:
# category
# Baby Care                   Quick DryHuggiesSlurrp FarmMee MeeHuggiesHimal...
# Bakery, Cakes & Dairy       CadburyGowardhanNutribeeEnglish OvenThe Baker'...
# Beauty & Hygiene            Sri Sri Ayurveda NiveaSatinanceBionovaStBotani...
# Beverages                   RealOctaviusPaper BoatWagh BakriNOCDSpriteTyph...
# Cleaning & Household        TrmNakodaNature ProtectScotch briteCloroxHerba...
# Eggs, Meat & Fish           IfbFreshoLa CarneFresho SignatureMeatzzaFresho...
# Foodgrains, Oil & Masala    NaturoBellSafe Harvestbb RoyalCatchOrganic Tat...
# Fruits & Vegetables         Supa CornFreshoFreshoFreshoFreshoFreshoFreshoF...
# Gourmet & World Food        NUTRASHILSapphireGraminwayTrue ElementsMurginn...
# Kitchen, Garden & Pets      MastercookIRICHCelloSteeloClassic EssentialsKv...
# Snacks & Branded Foods      Fit & FlexSwitzFabelleSpice StoryFabelleSharea...
# Name: brand, dtype: object

# %%
df[df.category=='Beverages']
# Out:
#        index                                    product   category  \
# 30        31             Fruit Power - Masala Sugarcane  Beverages
# 33        34               Green Tea - Tulsi Loose Leaf  Beverages
# 106      107                   Aamras Mango Fruit Juice  Beverages
# 116      117  Spiced Tea - Blend Of 7 Refreshing Spices  Beverages
# 170      171          BCAA Energy Drink - Berry Flavour  Beverages
# ...      ...                                        ...        ...
# 27391  27392              Water-based Electrolyte Drink  Beverages
# 27392  27393                    Juice - Mango, Aloevera  Beverages
# 27402  27403                     Classic Instant Coffee  Beverages
# 27474  27475                Green Tea Bags - Detox Pack  Beverages
# 27553  27554                  Green Tea - Pure Original  Beverages
#
#                 sub_category       brand  sale_price  market_price  \
# 30     Fruit Juices & Drinks        Real        19.0          20.0
# ...

# %%
df.describe()
# Out:
#              index     sale_price  market_price        rating
# count  27555.00000   27549.000000  27555.000000  18919.000000
# mean   13778.00000     334.648391    382.056664      3.943295
# std     7954.58767    1202.102113    581.730717      0.739217
# min        1.00000       2.450000      3.000000      1.000000
# 25%     6889.50000      95.000000    100.000000      3.700000
# 50%    13778.00000     190.320000    220.000000      4.100000
# 75%    20666.50000     359.000000    425.000000      4.300000
# max    27555.00000  112475.000000  12500.000000      5.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27555 entries, 0 to 27554
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   index         27555 non-null  int64
#  1   product       27554 non-null  object
#  2   category      27555 non-null  object
#  3   sub_category  27555 non-null  object
#  4   brand         27554 non-null  object
#  5   sale_price    27549 non-null  float64
#  6   market_price  27555 non-null  float64
#  7   type          27555 non-null  object
#  8   rating        18919 non-null  float64
#  9   description   27440 non-null  object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 2.1+ MB

# %%
df['product']
# Out:
# 0                   Garlic Oil - Vegetarian Capsule 500 mg
# 1                                    Water Bottle - Orange
# 2                           Brass Angle Deep - Plain, No.2
# 3        Cereal Flip Lid Container/Storage Jar - Assort...
# 4                       Creme Soft Soap - For Hands & Body
#                                ...
# 27550           Wottagirl! Perfume Spray - Heaven, Classic
# 27551                                             Rosemary
# 27552                         Peri-Peri Sweet Potato Chips
# 27553                            Green Tea - Pure Original
# 27554                       United Dreams Go Far Deodorant
# Name: product, Length: 27555, dtype: object

# %%
df['product'].unique
# Out:
# <bound method Series.unique of 0                   Garlic Oil - Vegetarian Capsule 500 mg
# 1                                    Water Bottle - Orange
# 2                           Brass Angle Deep - Plain, No.2
# 3        Cereal Flip Lid Container/Storage Jar - Assort...
# 4                       Creme Soft Soap - For Hands & Body
#                                ...
# 27550           Wottagirl! Perfume Spray - Heaven, Classic
# 27551                                             Rosemary
# 27552                         Peri-Peri Sweet Potato Chips
# 27553                            Green Tea - Pure Original
# 27554                       United Dreams Go Far Deodorant
# Name: product, Length: 27555, dtype: object>

# %%
df['sale_price'].max()
# Out:
# 112475.0

# %%
df['market_price'].max()
# Out:
# 12500.0

# %%
df[df.sale_price==df['sale_price'].max()]
# Out:
#       index    product          category    sub_category       brand  \
# 1249   1250  Beard Kit  Beauty & Hygiene  Men's Grooming  Uncle Tony
#
#       sale_price  market_price                type  rating  \
# 1249    112475.0        3300.0  Combos & Gift Sets     NaN
#
#                                             description
# 1249  The combination of a beard oil, a beard wash, ...

# %%
df[df.sale_price>5000]
# Out:
#        index                                            product  \
# 248      249  4mm Aluminium Induction Base Chapati Roti Tawa...
# 288      289          Arrabbiata Tomato Pasta Sauce With Chilli
# 436      437                       Balloon - Polka Dot, 12 Inch
# 935      936  Stainless Steel  Induction Compatible Pressure...
# 1056    1057  Gas Stove-3 Burner Royale Plus Schott Glass, B...
# 1249    1250                                          Beard Kit
# 1381    1382             Deodorant Body Spray - Man Freedom EDT
# 1740    1741      Deodorant Body Spray - Be Delicious Woman EDT
# 1766    1767                  Good Girl Eau De Parfum For Women
# 1769    1770                             Extra Virgin Olive Oil
# 2781    2782                             Extra Virgin Olive Oil
# 3605    3606                            Perfume - Men EDP Spray
# 3635    3636                     Perfume - Pure White Linen EDP
# 5464    5465                           Olive Oil - Extra Virgin
# ...

# %%
df.sale_price=np.where(df.sale_price>50000,df.market_price,df.sale_price)

# %%
df[df.sale_price>50000]
# Out:
# Empty DataFrame
# Columns: [index, product, category, sub_category, brand, sale_price, market_price, type, rating, description]
# Index: []

# %%
max=df['product'].value_counts()

# %%
#top selling products
most_seliing_products = max.idxmax()
most_seliing_products
# Out:
# 'Turmeric Powder/Arisina Pudi'

# %%
#least selling products
least_selling_product = max.idxmin()
least_selling_product
# Out:
# 'Chips - Mediterranean'

# %%
df
# Out:
#        index                                            product  \
# 0          1             Garlic Oil - Vegetarian Capsule 500 mg
# 1          2                              Water Bottle - Orange
# 2          3                     Brass Angle Deep - Plain, No.2
# 3          4  Cereal Flip Lid Container/Storage Jar - Assort...
# 4          5                 Creme Soft Soap - For Hands & Body
# ...      ...                                                ...
# 27550  27551         Wottagirl! Perfume Spray - Heaven, Classic
# 27551  27552                                           Rosemary
# 27552  27553                       Peri-Peri Sweet Potato Chips
# 27553  27554                          Green Tea - Pure Original
# 27554  27555                     United Dreams Go Far Deodorant
#
#                      category              sub_category  \
# 0            Beauty & Hygiene                 Hair Care
# 1      Kitchen, Garden & Pets     Storage & Accessories
# ...

# %%
# adding discount on items of 10%
df['discount']=df.sale_price-df.sale_price*0.10
df
# Out:
#        index                                            product  \
# 0          1             Garlic Oil - Vegetarian Capsule 500 mg
# 1          2                              Water Bottle - Orange
# 2          3                     Brass Angle Deep - Plain, No.2
# 3          4  Cereal Flip Lid Container/Storage Jar - Assort...
# 4          5                 Creme Soft Soap - For Hands & Body
# ...      ...                                                ...
# 27550  27551         Wottagirl! Perfume Spray - Heaven, Classic
# 27551  27552                                           Rosemary
# 27552  27553                       Peri-Peri Sweet Potato Chips
# 27553  27554                          Green Tea - Pure Original
# 27554  27555                     United Dreams Go Far Deodorant
#
#                      category              sub_category  \
# 0            Beauty & Hygiene                 Hair Care
# 1      Kitchen, Garden & Pets     Storage & Accessories
# ...

# %%
df.isnull().sum()
# Out:
# index              0
# product            1
# category           0
# sub_category       0
# brand              1
# sale_price         6
# market_price       0
# type               0
# rating          8636
# description      115
# discount           6
# dtype: int64

# %%
df[df.sale_price.isnull()]
# Out:
#       index                                            product  \
# 1719   1720            Puja Flower Wicks - Puvvu Vathulu Batti
# 1720   1721                                    Powder - Sambar
# 1721   1722  Steel Fork - Medium, Premium Excel Series, BBCL08
# 1722   1723                                 Snack Mix - Dhokla
# 2401   2402                              Battery AA 3UT Hi Top
# 2402   2403        Klassic Plain Cocktail Napkins (22 X 22 cm)
#
#                       category              sub_category       brand  \
# 1719      Cleaning & Household               Pooja Needs        Jaji
# 1720  Foodgrains, Oil & Masala          Masalas & Spices  Annapoorna
# 1721    Kitchen, Garden & Pets        Crockery & Cutlery     BB Home
# 1722    Snacks & Branded Foods       Ready To Cook & Eat         MTR
# 2401    Kitchen, Garden & Pets  Appliances & Electricals       Nippo
# 2402      Cleaning & Household  Disposables, Garbage Bag     Origami
#
# ...

# %%
df.sale_price.mean(),df.sale_price.median()
# Out:
# (323.4572409161857, 190.08)

# %%
df.sale_price=df.sale_price.fillna(df.market_price)

# %%
df[2401:2404]
# Out:
#       index                                      product  \
# 2401   2402                        Battery AA 3UT Hi Top
# 2402   2403  Klassic Plain Cocktail Napkins (22 X 22 cm)
# 2403   2404                Ultra Nights XXL+  With Wings
#
#                     category              sub_category     brand  sale_price  \
# 2401  Kitchen, Garden & Pets  Appliances & Electricals     Nippo       150.0
# 2402    Cleaning & Household  Disposables, Garbage Bag   Origami        32.0
# 2403        Beauty & Hygiene          Feminine Hygiene  Whisper        105.0
#
#       market_price                  type  rating  \
# 2401         150.0  Battery & Electrical     4.0
# 2402          32.0          Toilet Paper     3.9
# 2403         105.0      Sanitary Napkins     4.4
#
#                                             description  discount
# 2401  This Nippo battery incorporates state-of-the-a...       NaN
# 2402  Klassic Plain Cocktail Napkins (22 X 22 cm) 10...       NaN
# ...

# %%
df.brand.value_counts()
# Out:
# brand
# Fresho              638
# bb Royal            539
# BB Home             428
# DP                  250
# Fresho Signature    171
#                    ...
# Wellastrate           1
# Clean & Fresh         1
# Lal                   1
# Glint                 1
# Baron De Bercy        1
# Name: count, Length: 2313, dtype: int64

# %%
df.groupby('brand')['sale_price'].sum().sort_values(ascending=False)
# Out:
# brand
# Prestige      138190.00
# Dkny          114360.00
# bb Royal      114056.03
# BB Home       100160.50
# Hawkins        96857.50
#                 ...
# Cheetos           10.00
# Polo              10.00
# Dream Bake        10.00
# Narasus           10.00
# Livon              3.00
# Name: sale_price, Length: 2313, dtype: float64

# %%
x=df['product'].mode()[0]
df['product']=df['product'].fillna(x)

# %%
y=df.brand.mode()[0]
y
# Out:
# 'Fresho'

# %%
df.brand=df.brand.fillna(y)

# %%
a=df.sale_price.median()

# %%
df.sale_price=df.sale_price.fillna(a)

# %%
b=df.rating.mean()

# %%
df.rating=df.rating.fillna(b)

# %%
d=df.description.mode()[0]

# %%
df.description=df.description.fillna(d)

# %%
df.isnull().sum()
# Out:
# index           0
# product         0
# category        0
# sub_category    0
# brand           0
# sale_price      0
# market_price    0
# type            0
# rating          0
# description     0
# discount        6
# dtype: int64

# %%
df
# Out:
#        index                                            product  \
# 0          1             Garlic Oil - Vegetarian Capsule 500 mg
# 1          2                              Water Bottle - Orange
# 2          3                     Brass Angle Deep - Plain, No.2
# 3          4  Cereal Flip Lid Container/Storage Jar - Assort...
# 4          5                 Creme Soft Soap - For Hands & Body
# ...      ...                                                ...
# 27550  27551         Wottagirl! Perfume Spray - Heaven, Classic
# 27551  27552                                           Rosemary
# 27552  27553                       Peri-Peri Sweet Potato Chips
# 27553  27554                          Green Tea - Pure Original
# 27554  27555                     United Dreams Go Far Deodorant
#
#                      category              sub_category  \
# 0            Beauty & Hygiene                 Hair Care
# 1      Kitchen, Garden & Pets     Storage & Accessories
# ...

# %%
df.describe()
# Out:
#              index    sale_price  market_price        rating      discount
# count  27555.00000  27555.000000  27555.000000  27555.000000  27549.000000
# mean   13778.00000    323.409019    382.056664      3.943295    291.111517
# std     7954.58767    504.206130    581.730717      0.612516    453.823548
# min        1.00000      2.450000      3.000000      1.000000      2.205000
# 25%     6889.50000     95.000000    100.000000      3.943295     85.500000
# 50%    13778.00000    190.010000    220.000000      3.943295    171.072000
# 75%    20666.50000    359.000000    425.000000      4.200000    323.100000
# max    27555.00000  22325.000000  12500.000000      5.000000  20092.500000

# %%
import seaborn as sns

# %%
sns.boxplot(df.sale_price,orient='h')
# Out:
# <Axes: xlabel='sale_price'>

# %%
sns.boxplot(df.market_price,orient='h')
# Out:
# <Axes: xlabel='market_price'>

# %%
Q1,Q3=df.sale_price.quantile([0.25,0.75])
Q1,Q3
# Out:
# (95.0, 359.0)

# %%
IQR=Q3-Q1
IQR
# Out:
# 264.0

# %%
UL=Q3+1.5*(IQR)
LL=Q1-1.5*(IQR)
UL,LL
# Out:
# (755.0, -301.0)

# %%
df[df.sale_price>UL]
# Out:
#        index                                            product  \
# 8          9  Biotin & Collagen Volumizing Hair Shampoo + Bi...
# 47        48                              Colour Catcher Sheets
# 51        52                                        Peach Syrup
# 69        70             Padded Harness - 3/4 inch, Grey Colour
# 91        92    Hard Anodised Ezee-Pour Saucepan With Lid - L88
# ...      ...                                                ...
# 27498  27499            Juicer - Fruit & Vegetable, Light Green
# 27505  27506                                 Virgin Coconut Oil
# 27514  27515                     Verge & Sheer Perfume For Pair
# 27538  27539  Quista Pro Advanced Whey Protein Formula forti...
# 27542  27543                    Embellish Skin Lightening Serum
#
#                        category            sub_category            brand  \
# 8              Beauty & Hygiene               Hair Care       StBotanica
# ...

# %%
h=df.sale_price.mean()

# %%
df.sale_price=np.where(df.sale_price>UL,h,df.sale_price)

# %%
df[df.sale_price>UL]
# Out:
# Empty DataFrame
# Columns: [index, product, category, sub_category, brand, sale_price, market_price, type, rating, description, discount]
# Index: []

# %%
# outliers in market_price
Q1,Q3=df.market_price.quantile([0.25,0.75])
Q1,Q3
# Out:
# (100.0, 425.0)

# %%
IQR=Q3-Q1
IQR
# Out:
# 325.0

# %%
UL=Q3+1.5*(IQR)
LL=Q1-1.5*(IQR)
UL,LL
# Out:
# (912.5, -387.5)

# %%
df[df.market_price>UL]
# Out:
#        index                                            product  \
# 8          9  Biotin & Collagen Volumizing Hair Shampoo + Bi...
# 34        35               Pet Solitaire Container Set - Silver
# 96        97                    Hair Remover Spray - Foam Lemon
# 99       100         Wonder Diaper Pants - Xtra Large, 12-17 Kg
# 118      119           Adult Dry Cat Food - +1 Year, Ocean Fish
# ...      ...                                                ...
# 27488  27489                          Cranberry - Dried, Sliced
# 27498  27499            Juicer - Fruit & Vegetable, Light Green
# 27514  27515                     Verge & Sheer Perfume For Pair
# 27538  27539  Quista Pro Advanced Whey Protein Formula forti...
# 27542  27543                    Embellish Skin Lightening Serum
#
#                      category              sub_category            brand  \
# 8            Beauty & Hygiene                 Hair Care       StBotanica
# ...

# %%
t=df.market_price.mean()

# %%
df.market_price=np.where(df.market_price>UL,t,df.market_price)

# %%
df[df.market_price>UL]
# Out:
# Empty DataFrame
# Columns: [index, product, category, sub_category, brand, sale_price, market_price, type, rating, description, discount]
# Index: []

# %%
import matplotlib.pyplot as plt

# %%
df
# Out:
#        index                                            product  \
# 0          1             Garlic Oil - Vegetarian Capsule 500 mg
# 1          2                              Water Bottle - Orange
# 2          3                     Brass Angle Deep - Plain, No.2
# 3          4  Cereal Flip Lid Container/Storage Jar - Assort...
# 4          5                 Creme Soft Soap - For Hands & Body
# ...      ...                                                ...
# 27550  27551         Wottagirl! Perfume Spray - Heaven, Classic
# 27551  27552                                           Rosemary
# 27552  27553                       Peri-Peri Sweet Potato Chips
# 27553  27554                          Green Tea - Pure Original
# 27554  27555                     United Dreams Go Far Deodorant
#
#                      category              sub_category  \
# 0            Beauty & Hygiene                 Hair Care
# 1      Kitchen, Garden & Pets     Storage & Accessories
# ...

# %%
df.category.value_counts()
# Out:
# category
# Beauty & Hygiene            7867
# Gourmet & World Food        4690
# Kitchen, Garden & Pets      3580
# Snacks & Branded Foods      2814
# Foodgrains, Oil & Masala    2676
# Cleaning & Household        2675
# Beverages                    885
# Bakery, Cakes & Dairy        851
# Baby Care                    610
# Fruits & Vegetables          557
# Eggs, Meat & Fish            350
# Name: count, dtype: int64

# %%
plt.pie(df.category.value_counts(),labels=df.category.value_counts().index,autopct='%1.f%%')
plt.show()

# %%
df['type'].value_counts()
# Out:
# type
# Face Care                1508
# Ayurveda                  538
# Men's Deodorants          500
# Shampoo & Conditioner     461
# Glassware                 415
#                          ...
# Bagels & Baguette           1
# Roses                       1
# Marinated Meat              1
# Organic Eggs                1
# Turkey & Duck               1
# Name: count, Length: 426, dtype: int64

# %%
plt.pie(df.type.head(20).value_counts(),labels=df.type.head(20).value_counts().index,autopct='%1.f%%')
plt.show()

# %%
df
# Out:
#        index                                            product  \
# 0          1             Garlic Oil - Vegetarian Capsule 500 mg
# 1          2                              Water Bottle - Orange
# 2          3                     Brass Angle Deep - Plain, No.2
# 3          4  Cereal Flip Lid Container/Storage Jar - Assort...
# 4          5                 Creme Soft Soap - For Hands & Body
# ...      ...                                                ...
# 27550  27551         Wottagirl! Perfume Spray - Heaven, Classic
# 27551  27552                                           Rosemary
# 27552  27553                       Peri-Peri Sweet Potato Chips
# 27553  27554                          Green Tea - Pure Original
# 27554  27555                     United Dreams Go Far Deodorant
#
#                      category              sub_category  \
# 0            Beauty & Hygiene                 Hair Care
# 1      Kitchen, Garden & Pets     Storage & Accessories
# ...

# %%
df[df.brand=='Tetley'].value_counts().sum()
# Out:
# 13

# %%
df.type.max()
# Out:
# 'Yogurt & Shrikhand'
